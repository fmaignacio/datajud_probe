# %% [markdown]
# <a href="https://colab.research.google.com/github/fmaignacio/datajud_probe/blob/claude%2Fevaluate-legal-databases-yWU5P/10_vida_util_stj_enriquecida.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 10 - Vida Util STJ Enriquecida
#
# Objetivo: juntar ATA do STJ, movimentos do DataJud STJ e documentos do corpus do STJ para construir uma timeline unificada da vida util processual no STJ.

# %% [markdown]
# ## 1. Ambiente e entradas

# %%
from __future__ import annotations

import json
from pathlib import Path

import pandas as pd

try:
    from google.colab import drive
    IN_COLAB = True
except ImportError:
    IN_COLAB = False

if IN_COLAB:
    MOUNT_POINT = Path('/content/drive')
    if not (MOUNT_POINT / 'MyDrive').exists():
        drive.mount(str(MOUNT_POINT), force_remount=True)
    DATA_ROOT = MOUNT_POINT / 'MyDrive/Mestrado/2026/llms/data'
else:
    DATA_ROOT = Path.cwd().resolve().parents[0] / 'data'

PROCESSED_DATA = DATA_ROOT / 'processed'

process_spine = pd.read_parquet(PROCESSED_DATA / 'stj_processos_ciclo_vida.parquet')
ata_partes = pd.read_parquet(PROCESSED_DATA / 'stj_ata_partes.parquet')
ata_advogados = pd.read_parquet(PROCESSED_DATA / 'stj_ata_advogados.parquet')
documentos = pd.read_parquet(PROCESSED_DATA / 'stj_documentos_por_processo.parquet')
datajud_processos = pd.read_parquet(PROCESSED_DATA / 'stj_datajud_processos.parquet')
datajud_movimentos = pd.read_parquet(PROCESSED_DATA / 'stj_datajud_movimentos.parquet')

print('process_spine:', process_spine.shape)
print('documentos:', documentos.shape)
print('datajud_movimentos:', datajud_movimentos.shape)
# Out:
# Mounted at /content/drive
# process_spine: (2582, 37)
# documentos: (41128, 40)
# datajud_movimentos: (65819, 9)

# %%
def parse_mixed_datetime(series):
    as_str = series.astype("string").str.strip()

    # primeiro tenta o parser geral em UTC
    dt = pd.to_datetime(as_str, errors="coerce", utc=True)

    # fallback para formato compacto YYYYMMDDHHMMSS
    missing = dt.isna() & as_str.notna()
    if missing.any():
        dt.loc[missing] = pd.to_datetime(
            as_str.loc[missing],
            format="%Y%m%d%H%M%S",
            errors="coerce",
            utc=True,
        )

    # remove timezone para tudo ficar homogêneo
    return dt.dt.tz_localize(None)

# %% [markdown]
# ## 2. Normalizar eventos

# %%
ata_events = process_spine[['numero_processo', 'numero_registro_stj', 'data_primeira_distribuicao_stj', 'formas_distribuicao_stj', 'destinos_stj']].copy()
ata_events["event_datetime"] = parse_mixed_datetime(ata_events["data_primeira_distribuicao_stj"])
ata_events['event_source'] = 'ata_stj'
ata_events['event_type'] = 'distribuicao'
ata_events['event_label'] = ata_events['formas_distribuicao_stj']
ata_events['event_detail'] = ata_events['destinos_stj']

mov_events = datajud_movimentos[['numero_processo', 'numero_registro_stj', 'data_movimento', 'codigo_movimento', 'nome_movimento', 'complementos_tabelados']].copy()
mov_events["event_datetime"] = parse_mixed_datetime(mov_events["data_movimento"])
mov_events['event_source'] = 'datajud_stj'
mov_events['event_type'] = 'movimento'
mov_events['event_label'] = mov_events['nome_movimento']
mov_events['event_detail'] = mov_events['complementos_tabelados']

doc_events = documentos[['numero_processo', 'numero_registro_stj', 'data_documento', 'seq_documento', 'tipo_documento', 'ministro_documento']].copy()
doc_events["event_datetime"] = parse_mixed_datetime(doc_events["data_documento"])
doc_events['event_source'] = 'integra_stj'
doc_events['event_type'] = 'documento'
doc_events['event_label'] = doc_events['tipo_documento']
doc_events['event_detail'] = doc_events['ministro_documento']

# %% [markdown]
# ## 3. Unificar timeline

# %%
common_cols = ['numero_processo', 'numero_registro_stj', 'event_datetime', 'event_source', 'event_type', 'event_label', 'event_detail']
ata_events = ata_events[common_cols]
mov_events = mov_events[common_cols]
doc_events = doc_events[common_cols + ['seq_documento']]

process_events = pd.concat([ata_events, mov_events, doc_events], ignore_index=True, sort=False)
process_events['processo_agregacao'] = process_events['numero_processo'].combine_first(process_events['numero_registro_stj'])
process_events = process_events.sort_values(['processo_agregacao', 'event_datetime', 'event_source']).reset_index(drop=True)
process_events.head(20)
# Out:
#          numero_processo numero_registro_stj      event_datetime event_source  \
# 0   00000094820228272722        202301327446 2023-04-24 11:54:32  datajud_stj
# 1   00000094820228272722        202301327446 2023-04-27 16:15:08  datajud_stj
# 2   00000094820228272722        202301327446 2023-04-27 16:30:05  datajud_stj
# 3   00000094820228272722        202301327446 2023-05-15 18:30:17  datajud_stj
# 4   00000094820228272722        202301327446 2023-05-15 18:30:17  datajud_stj
# 5   00000094820228272722        202301327446 2023-05-16 19:11:45  datajud_stj
# 6   00000094820228272722        202301327446 2023-05-17 05:29:08  datajud_stj
# 7   00000094820228272722        202301327446 2023-05-23 19:28:06  datajud_stj
# 8   00000094820228272722        202301327446 2023-05-23 19:28:12  datajud_stj
# 9   00000094820228272722        202301327446 2023-05-23 19:31:00  datajud_stj
# 10  00000094820228272722        202301327446 2023-06-07 16:54:10  datajud_stj
# 11  00000094820228272722        202301327446 2023-06-07 16:56:00  datajud_stj
# 12  00000094820228272722        202301327446 2023-06-13 10:17:35  datajud_stj
# 13  00000094820228272722        202301327446 2023-06-13 10:21:00  datajud_stj
# 14  00000094820228272722        202301327446 2023-06-13 10:30:32  datajud_stj
# 15  00000094820228272722        202301327446 2023-06-29 14:30:23  datajud_stj
# 16  00000094820228272722        202301327446 2023-06-29 14:30:23  datajud_stj
# 17  00000094820228272722        202301327446 2023-06-29 18:37:00  datajud_stj
# 18  00000094820228272722        202301327446 2023-06-29 18:47:17  datajud_stj
# 19  00000094820228272722        202301327446 2023-06-29 19:25:57  datajud_stj
#
#    event_type                                       event_label  \
# 0   movimento                                       Recebimento
# 1   movimento                                      Distribuição
# 2   movimento                                         Conclusão
# 3   movimento                                   Mero expediente
# 4   movimento                                   Ato ordinatório
# 5   movimento  Disponibilização no Diário da Justiça Eletrônico
# 6   movimento                                        Publicação
# 7   movimento                              Protocolo de Petição
# 8   movimento                                       Recebimento
# 9   movimento                                           Petição
# 10  movimento                              Protocolo de Petição
# 11  movimento                                           Petição
# 12  movimento                              Protocolo de Petição
# 13  movimento                                           Petição
# 14  movimento                                         Conclusão
# 15  movimento                                   Mero expediente
# 16  movimento                                   Ato ordinatório
# 17  movimento                                           Remessa
# 18  movimento                                       Recebimento
# 19  movimento  Disponibilização no Diário da Justiça Eletrônico
#
#                                          event_detail seq_documento  \
# 0                                                None           NaN
# 1   [{"codigo": 2, "valor": 1, "nome": "competênci...           NaN
# 2   [{"codigo": 3, "valor": 6, "nome": "para decis...           NaN
# 3                                                None           NaN
# 4                                                None           NaN
# 5                                                None           NaN
# 6                                                None           NaN
# 7                                                None           NaN
# 8                                                None           NaN
# 9   [{"codigo": 19, "valor": 122, "nome": "Parecer...           NaN
# 10                                               None           NaN
# 11  [{"codigo": 19, "valor": 57, "nome": "Petição ...           NaN
# 12                                               None           NaN
# 13  [{"codigo": 19, "valor": 57, "nome": "Petição ...           NaN
# 14  [{"codigo": 3, "valor": 6, "nome": "para decis...           NaN
# 15                                               None           NaN
# 16                                               None           NaN
# 17  [{"codigo": 18, "valor": 40, "nome": "outros m...           NaN
# 18                                               None           NaN
# 19                                               None           NaN
#
#       processo_agregacao
# 0   00000094820228272722
# 1   00000094820228272722
# 2   00000094820228272722
# 3   00000094820228272722
# 4   00000094820228272722
# 5   00000094820228272722
# 6   00000094820228272722
# 7   00000094820228272722
# 8   00000094820228272722
# 9   00000094820228272722
# 10  00000094820228272722
# 11  00000094820228272722
# 12  00000094820228272722
# 13  00000094820228272722
# 14  00000094820228272722
# 15  00000094820228272722
# 16  00000094820228272722
# 17  00000094820228272722
# 18  00000094820228272722
# 19  00000094820228272722

# %% [markdown]
# ## 4. Agregar por processo

# %%
timeline_rows = []
for processo_key, group in process_events.groupby('processo_agregacao', dropna=True):
    records = group[['event_datetime', 'event_source', 'event_type', 'event_label', 'event_detail']].copy()
    records['event_datetime'] = records['event_datetime'].astype(str)
    timeline_rows.append({
        'processo_agregacao': processo_key,
        'numero_processo': group['numero_processo'].dropna().astype(str).iloc[0] if group['numero_processo'].notna().any() else None,
        'numero_registro_stj': group['numero_registro_stj'].dropna().astype(str).iloc[0] if group['numero_registro_stj'].notna().any() else None,
        'timeline_event_count': len(group),
        'timeline_start': group['event_datetime'].min(),
        'timeline_end': group['event_datetime'].max(),
        'timeline_json': json.dumps(records.to_dict('records'), ensure_ascii=False),
    })

process_timeline = pd.DataFrame(timeline_rows)
process_timeline.head()
# Out:
#      processo_agregacao       numero_processo numero_registro_stj  \
# 0  00000094820228272722  00000094820228272722        202301327446
# 1  00000195520128020001  00000195520128020001        202302129700
# 2  00000270520134047105  00000270520134047105        201700539640
# 3  00000461120218120012  00000461120218120012        202302183487
# 4  00000675420208190035  00000675420208190035        202300281603
#
#    timeline_event_count      timeline_start        timeline_end  \
# 0                   120 2023-04-24 11:54:32 2024-11-21 14:23:04
# 1                    58 2023-06-21 09:15:40 2024-02-26 18:53:06
# 2                    67 2017-03-15 19:24:06 2023-10-27 18:23:06
# 3                    60 2023-06-23 16:42:03 2025-12-15 18:51:07
# 4                    24 2023-02-02 13:21:43 2023-09-19 14:01:40
#
#                                        timeline_json
# 0  [{"event_datetime": "2023-04-24 11:54:32", "ev...
# 1  [{"event_datetime": "2023-06-21 09:15:40", "ev...
# 2  [{"event_datetime": "2017-03-15 19:24:06", "ev...
# 3  [{"event_datetime": "2023-06-23 16:42:03", "ev...
# 4  [{"event_datetime": "2023-02-02 13:21:43", "ev...

# %% [markdown]
# ## 5. Salvar artefatos

# %%
process_events.to_parquet(PROCESSED_DATA / 'stj_process_events.parquet', index=False)
process_timeline.to_parquet(PROCESSED_DATA / 'stj_process_timeline.parquet', index=False)

print('Salvos:')
print(PROCESSED_DATA / 'stj_process_events.parquet')
print(PROCESSED_DATA / 'stj_process_timeline.parquet')
# Out:
# Salvos:
# /content/drive/MyDrive/Mestrado/2026/llms/data/processed/stj_process_events.parquet
# /content/drive/MyDrive/Mestrado/2026/llms/data/processed/stj_process_timeline.parquet

# %%
# %%bash
# base="/content/drive/MyDrive/Mestrado/2026/llms/data/processed"
# for f in \
#   stj_processos_ciclo_vida.parquet \
#   stj_documentos_por_processo.parquet \
#   stj_datajud_processos.parquet \
#   stj_datajud_movimentos.parquet \
#   stj_datajud_assuntos.parquet
# do
#   if [ -f "$base/$f" ]; then
#     echo "OK  $f"
#   else
#     echo "MISS $f"
#   fi
# done
# Out:
# OK  stj_processos_ciclo_vida.parquet
# OK  stj_documentos_por_processo.parquet
# OK  stj_datajud_processos.parquet
# OK  stj_datajud_movimentos.parquet
# OK  stj_datajud_assuntos.parquet
